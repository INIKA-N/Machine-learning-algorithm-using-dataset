# %% [markdown]
# <a href="https://colab.research.google.com/github/INIKA-N/Machine-learning-algorithm-using-dataset/blob/main/Iris_dataset_for_Adaboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("/content/Iris.csv")
data.shape
data.isnull().sum()
data.set_index("Id",inplace=True)
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
y=data["Species"]
x=data.drop(columns='Species')
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
X_train_sub,X_test_sub,y_train_sub,y_test_sub = train_test_split(x,y,random_state=0)
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix
n_estimators = 600
ada = AdaBoostClassifier(n_estimators=n_estimators, random_state=0)
ada.fit(X_train_sub, y_train_sub)
# y_predicted=ada.predict(X_test_sub)
# results = pd.DataFrame({'Actual': y_test_sub, 'Predicted': y_predicted})
# print(results)
# accuracy = metrics.accuracy_score(y_test_sub, y_predicted)
print("Accuracy:", accuracy)
print("Accuracy score (training): {0:.3f}".format(ada.score(X_train_sub, y_train_sub)))
print("Accuracy score (validation): {0:.3f}".format(ada.score(X_test_sub, y_test_sub)))
# Out:
#               Actual        Predicted
# Id
# 115   Iris-virginica   Iris-virginica
# 63   Iris-versicolor  Iris-versicolor
# 34       Iris-setosa      Iris-setosa
# 108   Iris-virginica   Iris-virginica
# 8        Iris-setosa      Iris-setosa
# 101   Iris-virginica   Iris-virginica
# 41       Iris-setosa      Iris-setosa
# 87   Iris-versicolor  Iris-versicolor
# 77   Iris-versicolor  Iris-versicolor
# 72   Iris-versicolor  Iris-versicolor
# 135   Iris-virginica   Iris-virginica
# 52   Iris-versicolor  Iris-versicolor
# 74   Iris-versicolor  Iris-versicolor
# 55   Iris-versicolor  Iris-versicolor
# 64   Iris-versicolor  Iris-versicolor
# 38       Iris-setosa      Iris-setosa
# 79   Iris-versicolor  Iris-versicolor
# 91   Iris-versicolor  Iris-versicolor
# 46       Iris-setosa      Iris-setosa
# 17       Iris-setosa      Iris-setosa
# 122   Iris-virginica  Iris-versicolor
# 67   Iris-versicolor  Iris-versicolor
# 25       Iris-setosa      Iris-setosa
# ...
